# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
orange=pd.read_csv(r"C:\pandas_docs (2)\pandas_docs\Orange Quality Data.csv")

# %%
orange
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
#exploratory data analysis

# %%
orange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %%
orange.describe().T
# Out:
#                     count        mean        std    min    25%    50%    75%  \
# Size (cm)           241.0    7.844813   1.086002    6.0    6.9    7.8    8.7
# Weight (g)          241.0  205.128631  56.461012  100.0  155.0  205.0  252.0
# Brix (Sweetness)    241.0   10.907884   2.760446    5.5    8.5   11.0   13.4
# pH (Acidity)        241.0    3.473900   0.421007    2.8    3.2    3.4    3.8
# Softness (1-5)      241.0    3.072614   1.323630    1.0    2.0    3.0    4.0
# HarvestTime (days)  241.0   15.344398   5.323852    4.0   11.0   15.0   20.0
# Ripeness (1-5)      241.0    3.599585   1.205214    1.0    3.0    4.0    4.5
# Quality (1-5)       241.0    3.817427   1.014410    1.0    3.0    4.0    4.5
#
#                       max
# Size (cm)            10.0
# Weight (g)          300.0
# Brix (Sweetness)     16.0
# pH (Acidity)          4.4
# Softness (1-5)        5.0
# HarvestTime (days)   25.0
# Ripeness (1-5)        5.0
# Quality (1-5)         5.0

# %%
#checking null values

# %%
orange.isnull().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
#checking duplicates

# %%
orange.duplicated().sum()
# Out:
# 0

# %%
#unique values

# %%
orange.nunique()
# Out:
# Size (cm)              41
# Weight (g)            131
# Brix (Sweetness)       82
# pH (Acidity)           44
# Softness (1-5)          9
# HarvestTime (days)     22
# Ripeness (1-5)          8
# Color                   5
# Variety                24
# Blemishes (Y/N)        12
# Quality (1-5)           8
# dtype: int64

# %%
#checking value counts

# %%
orange.count()
# Out:
# Size (cm)             241
# Weight (g)            241
# Brix (Sweetness)      241
# pH (Acidity)          241
# Softness (1-5)        241
# HarvestTime (days)    241
# Ripeness (1-5)        241
# Color                 241
# Variety               241
# Blemishes (Y/N)       241
# Quality (1-5)         241
# dtype: int64

# %%
#orange color and type of veieties

# %%
orange[['Color','Variety']]
# Out:
#             Color            Variety
# 0          Orange           Valencia
# 1     Deep Orange              Navel
# 2    Light Orange          Cara Cara
# 3      Orange-Red       Blood Orange
# 4          Orange             Hamlin
# ..            ...                ...
# 236    Orange-Red          Tangerine
# 237  Light Orange  Minneola (Hybrid)
# 238   Deep Orange             Temple
# 239  Light Orange       Moro (Blood)
# 240    Orange-Red              Jaffa
#
# [241 rows x 2 columns]

# %%
a=orange['Softness (1-5)'].head(10)

# %%
a
# Out:
# 0    2.0
# 1    3.0
# 2    1.0
# 3    4.0
# 4    2.5
# 5    2.0
# 6    3.5
# 7    1.5
# 8    5.0
# 9    2.0
# Name: Softness (1-5), dtype: float64

# %%
b=orange['Color'].head(10)

# %%
#b=pd.DataFrame(a)

# %%
plt.plot(b,a,marker='*')
plt.title('color and softness ')
# Out:
# Text(0.5, 1.0, 'color and softness ')

# %%
plt.figure(figsize=(5,6))
plt.plot(b,a,marker='*',color='blue')
plt.xlabel('b')
plt.ylabel('a')
plt.xticks(rotation=90)
plt.title('****');

# %%
plt.hist(a)
# Out:
# (array([1., 1., 3., 1., 0., 1., 1., 1., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
s=orange['Weight (g)'].head()

# %%
s
# Out:
# 0    180
# 1    220
# 2    150
# 3    250
# 4    210
# Name: Weight (g), dtype: int64

# %%
size=orange['Size (cm)']

# %%
plt.hist(size)
plt.title('size of orange');

# %%
orange.hist(bins=10,edgecolor='red',color='green')
plt.suptitle('Histplot');
