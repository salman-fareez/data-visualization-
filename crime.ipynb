# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime=pd.read_csv(r"C:\Users\salma\Downloads\archive (5)\CrimesOnWomenData.csv")

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
pd.read_csv(r"C:\Users\salma\Downloads\archive (5)\description.csv")
# Out:
#    Unnamed: 0 Column Names                       Explanation
# 0           0        State                             State
# 1           1         Year                              Year
# 2           2         Rape                 No. of Rape cases
# 3           3          K&A                Kidnap And Assault
# 4           4           DD                      Dowry Deaths
# 5           5          AoW             Assault against women
# 6           6          AoM  Assault against modesty of women
# 7           7           DV                 Domestic violence
# 8           8           WT                 Women Trafficking

# %%
crime.isnull().sum()
# Out:
# Unnamed: 0    0
# State         0
# Year          0
# Rape          0
# K&A           0
# DD            0
# AoW           0
# AoM           0
# DV            0
# WT            0
# dtype: int64

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  736 non-null    int64
#  1   State       736 non-null    object
#  2   Year        736 non-null    int64
#  3   Rape        736 non-null    int64
#  4   K&A         736 non-null    int64
#  5   DD          736 non-null    int64
#  6   AoW         736 non-null    int64
#  7   AoM         736 non-null    int64
#  8   DV          736 non-null    int64
#  9   WT          736 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 57.6+ KB

# %%
crime.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(20,18))
sns.lineplot(x='Year',y='Rape',hue='State',data=crime)
plt.show()

# %%
plt.figure(figsize=(30,16))
sns.countplot(x='Rape',hue='State',data=crime)
plt.show()

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
st=crime.groupby('State')

# %%
bihar=st.get_group('BIHAR')
bihar
# Out:
#      Unnamed: 0  State  Year  Rape   K&A    DD  AoW  AoM    DV  WT
# 3             3  BIHAR  2001   888   518   859  562   21  1558  83
# 37           37  BIHAR  2002  1040   744   927  621    6  1577  38
# 71           71  BIHAR  2003   985   674   909  688   11  1880  37
# 105         105  BIHAR  2004  1390   997  1029  704   13  2679  35
# 139         139  BIHAR  2005  1147   929  1014  451   13  1574  74
# 173         173  BIHAR  2006  1232  1084  1188  530   53  1689  42
# 207         207  BIHAR  2007  1555  1260  1172  853   12  1635  56
# 241         241  BIHAR  2008  1302  1789  1210  999   21  1992  22
# 275         275  BIHAR  2009   929  1986  1295  726   12  2532  31
# 309         309  BIHAR  2010   795  2569  1257  534   16  2271   8

# %%
sns.barplot(x='Year',y='Rape',hue='State',data=bihar)
plt.title('number of rape cases in bihar')
plt.show()

# %%
sns.lineplot(x='Year',y='Rape',hue='State',data=bihar)
# Out:
# <Axes: xlabel='Year', ylabel='Rape'>

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
crime['State'].head(50)
# Out:
# 0        ANDHRA PRADESH
# 1     ARUNACHAL PRADESH
# 2                 ASSAM
# 3                 BIHAR
# 4          CHHATTISGARH
# 5                   GOA
# 6               GUJARAT
# 7               HARYANA
# 8      HIMACHAL PRADESH
# 9       JAMMU & KASHMIR
# 10            JHARKHAND
# 11            KARNATAKA
# 12               KERALA
# 13       MADHYA PRADESH
# 14          MAHARASHTRA
# 15              MANIPUR
# 16            MEGHALAYA
# 17              MIZORAM
# 18             NAGALAND
# 19               ODISHA
# 20               PUNJAB
# 21            RAJASTHAN
# 22               SIKKIM
# 23           TAMIL NADU
# 24              TRIPURA
# 25        UTTAR PRADESH
# 26          UTTARAKHAND
# 27          WEST BENGAL
# 28        A & N ISLANDS
# 29           CHANDIGARH
# 30         D & N HAVELI
# 31          DAMAN & DIU
# 32          LAKSHADWEEP
# 33           PUDUCHERRY
# 34       ANDHRA PRADESH
# 35    ARUNACHAL PRADESH
# 36                ASSAM
# 37                BIHAR
# ...

# %%
kerala=crime[crime["State"]=='KERALA']
kerala
# Out:
#      Unnamed: 0   State  Year  Rape  K&A  DD   AoW  AoM    DV  WT
# 12           12  KERALA  2001   562   97  27  1942   81  2561   0
# 46           46  KERALA  2002   499   91  17  2123  102  2836   0
# 80           80  KERALA  2003   394  102  33  1947   68  2930   0
# 114         114  KERALA  2004   480  142  31  2260  133  3222   0
# 148         148  KERALA  2005   478  129  21  2339  175  3283   0
# 182         182  KERALA  2006   601  202  25  2543  222  3708   0
# 216         216  KERALA  2007   512  177  27  2624  262  3999   0
# 250         250  KERALA  2008   568  166  31  2745  258  4138   0
# 284         284  KERALA  2009   568  173  20  2540  395  4007   0
# 318         318  KERALA  2010   634  184  22  2936  537  4797   0

# %%
sns.lineplot(x='Year',y='K&A',data=kerala)
plt.title('Kidnap And Assault in kerala')
plt.show()

# %%
sns.barplot(x='Year',y='K&A',data=kerala)
plt.title('Kidnap And Assault in kerala')
plt.show()

# %%
numeric=crime.corr(numeric_only=True)

# %%
sns.heatmap(numeric,annot=True,cmap='magma');

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
sns.scatterplot(x='AoW',y='DD',hue='Year',data=crime)
plt.show()

# %%
sns.boxplot(crime)
plt.xticks(rotation=90)
plt.show()

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
sns.jointplot(x='AoW',y='AoM',color='red',data=crime)
plt.show()

# %%
crime
# Out:
#      Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  \
# 0             0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791
# 1             1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11
# 2             2              ASSAM  2001   817  1070   59   850     4  1248
# 3             3              BIHAR  2001   888   518  859   562    21  1558
# 4             4       CHHATTISGARH  2001   959   171   70  1763   161   840
# ..          ...                ...   ...   ...   ...  ...   ...   ...   ...
# 731         731         D&N Haveli  2021  1250  4083  141  2068   417  4731
# 732         732        Daman & Diu  2021   315   904   16  1851    10   501
# 733         733           Delhi UT  2021     2     1    0     5     1     9
# 734         734        Lakshadweep  2021     0     0    0     1     1     3
# 735         735         Puducherry  2021     2     0    2    31     3    12
#
#      WT
# 0     7
# 1     0
# 2     0
# 3    83
# ...

# %%
year_data = crime[crime['Year'] == 2021]
plt.figure(figsize=(12, 6))
sns.barplot(x='Rape',y='State',data=year_data,)
plt.title('Total Rape Cases by State (2021)')
plt.xlabel('Number of Rape Cases')
plt.ylabel('States')
plt.show()

# %%
andhra= crime[crime['State'] == 'ANDHRA PRADESH']
plt.figure(figsize=(10, 5))
sns.lineplot(x='Year', y='Rape', data=andhra, marker='o')
plt.title('Rape Cases Over the Years in Andhra Pradesh')
plt.xlabel('Year')
plt.ylabel('Number of Rape Cases')
plt.show()
